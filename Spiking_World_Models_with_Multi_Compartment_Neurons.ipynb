# %% [markdown]
# <a href="https://colab.research.google.com/github/JoChi-Sun/braincog-cifar10-demo/blob/main/Spiking_World_Models_with_Multi_Compartment_Neurons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brain-Cog 框架 Colab 執行範本
#
# **說明**：本 Notebook 演示如何在 Google Colab 上跑 Brain-Cog（2022）的開源專案，並示範一個簡單範例（Image Classification）。
#
# ---
#
#  1. 環境準備
#
# 在 Colab 中，先確認 GPU 已啟用：
# - 點選上方選單 `執行階段` → `變更執行階段類型` → 選擇 `GPU` → 儲存。

# %%
import torch
print("CUDA available:", torch.cuda.is_available(), "| Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA available: True | Device: Tesla T4

# %% [markdown]
# 2. Clone Brain-Cog Repo

# %%
# 2.1 Clone 專案到 /content/brain-cog
# !git clone https://github.com/BrainCog-X/Brain-Cog.git /content/brain-cog
# 切換到專案目錄
# %cd /content/brain-cog
# 確認檔案結構
# !ls -R | sed -e 's/\(.*\)/\1/' | head -n 50
# Out:
# Cloning into '/content/brain-cog'...
# remote: Enumerating objects: 3758, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 3758 (delta 335), reused 237 (delta 226), pack-reused 3355 (from 3)
# Receiving objects: 100% (3758/3758), 3.56 MiB | 7.78 MiB/s, done.
# Resolving deltas: 100% (1834/1834), done.
# /content/brain-cog
# .:
# braincog
# docs
# docs.md
# documents
# examples
# LICENSE
# README.md
# requirements.txt
# setup.py
#
# ./braincog:
# base
# datasets
# __init__.py
# model_zoo
# utils.py
#
# ./braincog/base:
# brainarea
# connection
# conversion
# encoder
# __init__.py
# learningrule
# node
# strategy
# utils
#
# ./braincog/base/brainarea:
# basalganglia.py
# BrainArea.py
# dACC.py
# __init__.py
# Insula.py
# IPL.py
# PFC.py
#
# ./braincog/base/connection:
# CustomLinear.py
# __init__.py
# layer.py
#
# ./braincog/base/conversion:
# convertor.py
# __init__.py
# merge.py
# spicalib.py
#
# ...

# %% [markdown]
# 3.安裝套件

# %%
# 3.1 安裝官方 requirements.txt 內定義的套件
# !pip install -r requirements.txt

# 3.2 額外可能需要的套件（視情況補裝）
# !pip install torch torchvision torchaudio        # 若 Colab 預設版本不符，可強制覆蓋
# !pip install matplotlib opencv-python pandas tqdm scikit-learn
# !pip install imageio imageio-ffmpeg
# !pip install seaborn                              # 視需要做資料可視化時
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.1/666.1 kB 22.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 43.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# 4. 測試執行：跑 Image Classification 範例

# %%
# %cd /content/brain-cog/examples/Perception_and_Learning/img_cls/bp
# Out:
# /content/brain-cog/examples/Perception_and_Learning/img_cls/bp

# %% [markdown]
# 把 brain-cog 當作可編輯套件安裝（讓 Python 能 import braincog）

# %%
# %cd /content/brain-cog
# !pip install -e .
# Out:
# /content/brain-cog
# Obtaining file:///content/brain-cog
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for braincog
# ...

# %%
# %cd /content/brain-cog/examples/Perception_and_Learning/img_cls/bp

# !python main.py \
    --model cifar_convnet \
    --dataset cifar10 \
    --node-type LIFNode \
    --step 8 \
    --device 0 \
    --epochs 2
# Out:
# /content/brain-cog/examples/Perception_and_Learning/img_cls/bp
# 2025-06-03 09:45:14.743372: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748943914.763165   15252 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748943914.769445   15252 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-03 09:45:14.789885: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
